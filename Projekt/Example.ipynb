# %%
import pandas as pd

# %% [markdown]
# # Read data

# %%
train = pd.read_csv('train_data.csv')
test = pd.read_csv('test_data.csv')
submission = pd.read_csv('example_submission.csv')

# %%
# dane treningowe, y to kolumna 'Survived'
train
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 795          796         0       2    male  39.0      0      0
# 796          797         1       1  female  49.0      0      0
# 797          798         1       3  female  31.0      0      0
# 798          799         0       3    male  30.0      0      0
# 799          800         0       3  female  30.0      1      1
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
# dane testowe
test
# Out:
#     PassengerId  Pclass     Sex    Age  SibSp  Parch      Ticket      Fare  \
# 0           801       2    male  34.00      0      0      250647   13.0000
# 1           802       2  female  31.00      1      1  C.A. 31921   26.2500
# 2           803       1    male  11.00      1      2      113760  120.0000
# 3           804       3    male   0.42      0      1        2625    8.5167
# 4           805       3    male  27.00      0      0      347089    6.9750
# ..          ...     ...     ...    ...    ...    ...         ...       ...
# 86          887       2    male  27.00      0      0      211536   13.0000
# 87          888       1  female  19.00      0      0      112053   30.0000
# 88          889       3  female    NaN      1      2  W./C. 6607   23.4500
# 89          890       1    male  26.00      0      0      111369   30.0000
# 90          891       3    male  32.00      0      0      370376    7.7500
#
#       Cabin Embarked
# 0       NaN        S
# 1       NaN        S
# ...

# %%
# przykładowy output
submission
# Out:
#     Survived
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 86         0
# 87         0
# 88         0
# 89         0
# 90         0
#
# [91 rows x 1 columns]

# %% [markdown]
# # Jak działać?

# %% [markdown]
# 1. Pretwarzamy dane
# 2. Trenujemy model na danych treningowych
# 3. Uruchamiamy model na danych testowych
# 4. Zapisujemy nasz output korzystając z pandas

# %% [markdown]
# # Jak zapisać output?

# %%
# przykładowo, nasz algorytm sklasyfikował wszystkie próbki jako 1
output = pd.DataFrame(data=[1 for i in range(len(submission))], columns=['Survived'])

# %%
output
# Out:
#     Survived
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ..       ...
# 86         1
# 87         1
# 88         1
# 89         1
# 90         1
#
# [91 rows x 1 columns]

# %%
output.to_csv('our_submission.csv', index=None)
